# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Elizabeth Hunt**<br>
# Manager of Business Analytics

# %% [markdown]
# *I am interested in Data Analytics because i love numbers and puzzles and it pays well*

# %% [markdown]
# ### The below code will calculate the value of 56 times 47

# %%
print (56*47)
# Out:
# 2632

# %% [markdown]
# Two reasons I love data
# 1. it's awesome
# 2. it pays well
#
# Other things you should know
# * I have a business
# * It's called __[OptoOrg](http://www.optoorg.com)__
